# %%
#importing libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#data set importing
data_set=pd.read_csv("C:/Users/91965/Desktop/tp-imp/summer-AI/datasets/spam.csv")

# %%
#checking data set is import perfectly or not
data_set.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
#checking how many rows in data set
data_set.shape
# Out:
# (5572, 2)

# %%
# checking null values are present in data set or not
data_set.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
# dividing data set into input data and output data
in_data=data_set['Message']
out_data=data_set['Category']
# checking data is divided or not
print(in_data)
print(out_data)
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                 Will ü b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: Message, Length: 5572, dtype: object
# 0        ham
# 1        ham
# 2       spam
# 3        ham
# 4        ham
#         ...
# 5567    spam
# 5568     ham
# 5569     ham
# 5570     ham
# 5571     ham
# Name: Category, Length: 5572, dtype: object

# %%
# perform Label Encode operation without using LabelEncoder function
data_set.loc[data_set['Category']=="ham",'Category']=0

# %%
data_set.head()
# Out:
#   Category                                            Message
# 0        0  Go until jurong point, crazy.. Available only ...
# 1        0                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        0  U dun say so early hor... U c already then say...
# 4        0  Nah I don't think he goes to usf, he lives aro...

# %%
out_data.loc[out_data=="ham"]=0

# %%
out_data.head()
# Out:
# 0       0
# 1       0
# 2    spam
# 3       0
# 4       0
# Name: Category, dtype: object

# %%
out_data.loc[out_data=="spam"]=1

# %%
out_data.tail()
# Out:
# 5567    1
# 5568    0
# 5569    0
# 5570    0
# 5571    0
# Name: Category, dtype: object

# %%
# dtype:object convert into integer for better understand the model
out_data=out_data.astype(int)

# %%
out_data.tail()
# Out:
# 5567    1
# 5568    0
# 5569    0
# 5570    0
# 5571    0
# Name: Category, dtype: int32

# %%
# to convert alphabetical into numerical data
extraction=TfidfVectorizer(lowercase=True, min_df=1, stop_words="english")
# in above parameters are 
# "lowercase=True" it means all the words convert into lower case letters 
# ==> because this function consider Dog and dog two different words
# "min_df=1" it means consider the words which are greater than 1 otherwise it will not consider
# stop_words are nothing but nouns,prounouns,helping verbs etc these words are removes 
# ==> because these words are repeated several times in sentance

# %%
in_data_extract=extraction.fit_transform(in_data)

# %%
print(in_data_extract)
# Out:
#   (0, 8079)	0.1961033223643189
#   (0, 1061)	0.35097479377088364
#   (0, 3511)	0.16453831818791093
#   (0, 2003)	0.29650492406235857
#   (0, 1713)	0.3350433781715565
#   (0, 4370)	0.29650492406235857
#   (0, 8281)	0.23740715800944148
#   (0, 3551)	0.19387866945820545
#   (0, 1715)	0.29650492406235857
#   (0, 1281)	0.26251769953088055
#   (0, 2278)	0.27180581777101714
#   (0, 5775)	0.27451666535585145
#   (0, 4244)	0.35097479377088364
#   (1, 5399)	0.5466243141314314
#   (1, 8187)	0.43162957585464123
#   (1, 4212)	0.5236804332035243
#   (1, 4406)	0.4083258549263009
#   (1, 5373)	0.2718944069420321
#   (2, 77)	0.23775471426296338
#   (2, 1138)	0.1708958200698438
#   (2, 6100)	0.1708958200698438
#   (2, 7750)	0.12585247610650566
#   (2, 7073)	0.19910160498748308
#   (2, 6048)	0.1809617113309815
#   (2, 6154)	0.16925521015250053
#   :	:
#   (5567, 464)	0.2345392769367673
#   (5567, 5146)	0.2445509910362817
#   (5567, 8256)	0.1919079652601193
#   (5567, 2009)	0.18662411374983587
# ...

# %%
# slpiting data into traing data and testing data
in_train,in_test,out_train,out_test=train_test_split(in_data_extract,out_data,test_size=0.3,random_state=5,stratify=out_data)

# %%
# checking size of the data
print(in_data_extract.shape)
print(in_train.shape)
print(out_train.shape)
print(in_test.shape)
print(out_test.shape)
# Out:
# (5572, 8440)
# (3900, 8440)
# (3900,)
# (1672, 8440)
# (1672,)

# %%
# create logistic regression model
model=LogisticRegression()

# %%
# train model with training data
model.fit(in_train,out_train)
# Out:
# LogisticRegression()

# %%
# checking accuracy in training data
train_pred=model.predict(in_train)
train_accu=accuracy_score(out_train,train_pred)
print("accuracy is:",train_accu)
# Out:
# accuracy is: 0.9651282051282051

# %%
# checking accuracy in testing data
test_pred=model.predict(in_test)
test_accu=accuracy_score(out_test,test_pred)
print("accuracy is:",test_accu)
# Out:
# accuracy is: 0.9431818181818182

# %%
mail=input()
obj_mail=[mail]
mail_extract=extraction.transform(obj_mail)
print(mail_extract)
prediction=model.predict(mail_extract)
if(pred==1):
    print("it is a spam mail")
else:
    print("it is a ham mail or normal mail")
# Out:
#  Dear Participant,  It is our pleasure to invite you to Final round of “Smart Hacks 2K24 - β Edition”, a 48-hour National Level Hackathon presented by IEEE CIS AU SBC in collaboration with Coding Cubs and Department of Artificial Intelligence, scheduled to take place from June 20 to June 22, 2024 at Anurag University  In this regard, we request you to go through the essential information that you need to know prior the event
#   (0, 41)	0.14907119849998599
#   (0, 40)	0.14907119849998599
#   (0, 39)	0.14907119849998599
#   (0, 38)	0.14907119849998599
#   (0, 37)	0.14907119849998599
#   (0, 36)	0.14907119849998599
#   (0, 35)	0.14907119849998599
#   (0, 34)	0.14907119849998599
#   (0, 33)	0.14907119849998599
#   (0, 32)	0.14907119849998599
#   (0, 31)	0.14907119849998599
#   (0, 30)	0.14907119849998599
#   (0, 29)	0.14907119849998599
#   (0, 28)	0.14907119849998599
#   (0, 27)	0.14907119849998599
#   (0, 26)	0.14907119849998599
#   (0, 25)	0.29814239699997197
# ...
