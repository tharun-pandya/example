# %%
import numpy as np
import pandas as pd
import sklearn as sk
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data_set=pd.read_csv("C:\\Users\\91965\\Desktop\\tp-imp\\summer-AI\\datasets\\creditcard.csv")

# %%
data_set.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data_set.shape
# Out:
# (284807, 31)

# %%
data_set.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data_set.std()
# Out:
# Time      47488.145955
# V1            1.958696
# V2            1.651309
# V3            1.516255
# V4            1.415869
# V5            1.380247
# V6            1.332271
# V7            1.237094
# V8            1.194353
# V9            1.098632
# V10           1.088850
# V11           1.020713
# V12           0.999201
# V13           0.995274
# V14           0.958596
# V15           0.915316
# V16           0.876253
# V17           0.849337
# V18           0.838176
# V19           0.814041
# V20           0.770925
# V21           0.734524
# V22           0.725702
# V23           0.624460
# V24           0.605647
# V25           0.521278
# V26           0.482227
# V27           0.403632
# V28           0.330083
# Amount      250.120109
# Class         0.041527
# dtype: float64

# %%
data_set.Class
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
data_set.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
credit=data_set[data_set.Class==1]

# %%
print(credit)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
farud=data_set[data_set.Class==0]

# %%
print(credit.shape)
print(farud.shape)
# Out:
# (492, 31)
# (284315, 31)

# %%
farud=farud.sample(500)

# %%
print(farud.shape)
# Out:
# (500, 31)

# %%
# 0==>row
# 1==>column
new_data_set=pd.concat([credit,farud], axis=0)

# %%
print(new_data_set)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 251863  155534.0  1.494616 -1.225000 -1.538000  0.359205 -0.313184 -0.410781
# 142046   84561.0  1.246394 -0.428828  0.885480 -0.715522 -1.306377 -0.848547
# 142824   84962.0 -0.087999 -3.125021  0.360942  0.185731 -2.106185  0.401482
# 266818  162493.0 -0.080261  0.413198  1.103048 -1.494951  0.834285  0.125379
# 44823    42098.0  1.199111 -0.283225 -0.293800  0.285937  1.557405  4.089768
#
# ...

# %%
data=new_data_set.drop(["Class"],axis=1)

# %%
data
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 251863  155534.0  1.494616 -1.225000 -1.538000  0.359205 -0.313184 -0.410781
# 142046   84561.0  1.246394 -0.428828  0.885480 -0.715522 -1.306377 -0.848547
# 142824   84962.0 -0.087999 -3.125021  0.360942  0.185731 -2.106185  0.401482
# 266818  162493.0 -0.080261  0.413198  1.103048 -1.494951  0.834285  0.125379
# 44823    42098.0  1.199111 -0.283225 -0.293800  0.285937  1.557405  4.089768
#
# ...

# %%
output=new_data_set.Class

# %%
output
# Out:
# 541       1
# 623       1
# 4920      1
# 6108      1
# 6329      1
#          ..
# 251863    0
# 142046    0
# 142824    0
# 266818    0
# 44823     0
# Name: Class, Length: 992, dtype: int64

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# dtype: int64

# %%
data.std()
# Out:
# Time      48263.593246
# V1            5.509338
# V2            3.684841
# V3            6.190688
# V4            3.229457
# V5            4.214078
# V6            1.779166
# V7            5.866124
# V8            4.837871
# V9            2.305994
# V10           4.495200
# V11           2.779112
# V12           4.587384
# V13           1.036110
# V14           4.668210
# V15           0.970491
# V16           3.492933
# V17           5.950011
# V18           2.383071
# V19           1.295430
# V20           1.127787
# V21           2.780776
# V22           1.159764
# V23           1.170497
# V24           0.572360
# V25           0.664910
# V26           0.479902
# V27           1.000286
# V28           0.648655
# Amount      240.253404
# dtype: float64

# %%
scaler=StandardScaler()

# %%
data=scaler.fit_transform(data)

# %%
print(scaler)
# Out:
# StandardScaler()

# %%
StandardScaler()
# Out:
# StandardScaler()

# %%
print(StandardScaler())
# Out:
# StandardScaler()

# %%
scaler.fit_transform(data)
# Out:
# array([[-1.81317421,  0.0052268 ,  0.04782996, ...,  0.17074673,
#         -0.30563778, -0.45306837],
#        [-1.81180603, -0.12758098, -1.3394421 , ..., -0.34328352,
#         -0.02948098,  1.74988411],
#        [-1.72909332,  0.00683887, -0.00450386, ..., -0.05088063,
#         -0.32068098,  0.54608926],
#        ...,
#        [-0.06032811,  0.40914998, -1.33067594, ..., -0.1537873 ,
#          0.14281452,  2.57617869],
#        [ 1.54688972,  0.41055518, -0.36998198, ..., -0.21766273,
#         -0.36749335, -0.41142466],
#        [-0.94889894,  0.64289127, -0.55907392, ..., -0.0176518 ,
#         -0.03522286, -0.40309592]])

# %%
data.std()
# Out:
# 1.0

# %%
output.std()
# Out:
# 0.500235939254717

# %%
#random_sate is mandatory because if you not use it then data splited into same order so in that order to possible to maximum same label data
train_data,test_data,train_output,test_output=train_test_split(data,output,test_size=0.2,random_state=2)

# %%
print(train_data.shape,test_data.shape,test_output.shape,train_output.shape)
# Out:
# (793, 30) (199, 30) (199,) (793,)

# %%
model=LogisticRegression()

# %%
model.fit(train_data, train_output)
# Out:
# LogisticRegression()

# %%
model=LogisticRegression()

# %%
model.fit(train_data, train_output)
# Out:
# LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
prediction=model.predict(train_data)
print(accuracy_score(prediction,train_output))
# Out:
# 0.9533417402269861

# %%
print(test_data[4])
type(test_data[4])
print(test_output.head(4))
# Out:
# [ 1.24703023  0.23375184  0.70241045 -0.40563991  0.95360294  0.71653712
#  -0.85973464  0.20363609  0.06644122 -1.19628001 -0.76603053  0.59950024
#  -1.0610905  -1.59753941 -1.93209877 -0.18933057  0.1686693   0.01164496
#   0.50808536 -1.64783681  0.30972423  0.01321626 -0.84238615 -0.30875534
#  -0.31122087  0.34989702  0.01710518  0.75694944  0.73582271 -0.45306837]
# 114026    0
# 28225     0
# 93667     0
# 76609     1
# Name: Class, dtype: int64

# %%
prediction=model.predict(test_data[50])
print(accuracy_score(prediction,test_output[50]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 prediction=model.predict(test_data[50])
#       2 print(accuracy_score(prediction,test_output[50]))
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:451, in LinearClassifierMixin.predict(self, X)
#     437 """
#     438 Predict class labels for samples in X.
#     439
#    (...)
#     448     Vector containing the class labels for each sample.
#     449 """
#     450 xp, _ = get_namespace(X)
# --> 451 scores = self.decision_function(X)
#     452 if len(scores.shape) == 1:
#     453     indices = xp.astype(scores > 0, int)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:432, in LinearClassifierMixin.decision_function(self, X)
#     429 check_is_fitted(self)
#     430 xp, _ = get_namespace(X)
# --> 432 X = self._validate_data(X, accept_sparse="csr", reset=False)
# ...

# %%
test=np.array([1.25735916,  0.25494319,  0.68719207, -0.41454708,  0.95744635,  0.71816305,
 -0.87406822,  0.21244428,  0.07392678, -1.18200602, -0.76809616,  0.59775941,
 -1.06039814, -1.51916093, -1.93547996, -0.19474545,  0.17921364,  0.00519832,
  0.4992012,  -1.65521731,  0.33745587,  0.02068126, -0.81656034, -0.31880562,
 -0.26065374,  0.38305472,  0.02527413,  0.75385675,  1.12895571, -0.44919079])
test=test.reshape(1,-1)
prediction=model.predict(test)
if prediction==1:
    print("credited")
else:
    print("farud credit")
print("accuracy speed is:",accuracy_score(prediction,np.array([1])))
# Out:
# credited
# accuracy speed is: 1.0

# %%
test=np.array([1.64955365,  0.07684247, -0.82725889,  0.37272214, -0.36295692,  0.36218296,
  0.64110136,  1.12583232, -0.29220099,  0.53777107,  0.89721418, -0.30479038,
  0.52569256, -1.38744561,  0.81808406,  0.32210805,  0.4655699,   0.41043405,
  0.6782673,   0.4257949,  -0.13838661, -0.23532565,  0.4896069,   0.41719115,
  1.42025494, -0.21741458, -1.34609195,  0.41449553, -0.30430553,  2.54349614,])
test=test.reshape(1,-1)
prediction=model.predict(test)
if prediction==1:
    print("credited")
else:
    print("farud credit")
print("accuracy speed is:",accuracy_score(prediction,np.array([0])))
# Out:
# farud credit
# accuracy speed is: 1.0

# %%
testing=model.predict(test_data)
accuracy_test=accuracy_score(testing,test_output)
print(accuracy_test)
# Out:
# 0.9346733668341709

# %%
print(test)
# Out:
# [[ 1.64955365  0.07684247 -0.82725889  0.37272214 -0.36295692  0.36218296
#    0.64110136  1.12583232 -0.29220099  0.53777107  0.89721418 -0.30479038
#    0.52569256 -1.38744561  0.81808406  0.32210805  0.4655699   0.41043405
#    0.6782673   0.4257949  -0.13838661 -0.23532565  0.4896069   0.41719115
#    1.42025494 -0.21741458 -1.34609195  0.41449553 -0.30430553  2.54349614]]
